# %%
#!pip3 install ultralytics
# Out:
# ...
#   Using cached ultralytics-8.4.46-py3-none-any.whl (1.2 MB)
# ...
#   Using cached ultralytics_thop-2.0.19-py3-none-any.whl (28 kB)
# ...
#   Using cached pyyaml-6.0.3-cp310-cp310-win_amd64.whl (158 kB)
# ...
#   Using cached polars-1.40.1-py3-none-any.whl (828 kB)
# ...
#   Using cached opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl (40.2 MB)
# ...
#   Using cached requests-2.33.1-py3-none-any.whl (64 kB)
# ...
#   Using cached matplotlib-3.10.9-cp310-cp310-win_amd64.whl (8.2 MB)
# ...
#   Using cached torchvision-0.26.0-cp310-cp310-win_amd64.whl (3.7 MB)
# ...
#   Using cached polars_runtime_32-1.40.1-cp310-abi3-win_amd64.whl (51.8 MB)
# ...
#   Using cached charset_normalizer-3.4.7-cp310-cp310-win_amd64.whl (159 kB)
# ...
#   Using cached idna-3.13-py3-none-any.whl (68 kB)
# ...
#   Using cached certifi-2026.4.22-py3-none-any.whl (135 kB)
# ...
#   Using cached urllib3-2.6.3-py3-none-any.whl (131 kB)
# ...

# %%
from ultralytics import YOLO
# Out:
# c:\Users\sksaa\OneDrive\Desktop\smartVision AI\.venv1\lib\site-packages\torch\nn\modules\transformer.py:20: UserWarning: Failed to initialize NumPy: DLL load failed while importing _multiarray_umath: The specified module could not be found. (Triggered internally at ..\torch\csrc\utils\tensor_numpy.cpp:84.)
#   device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),

# %%
model = YOLO("yolov8s.pt")   # small + fast

# %%
#import torch
#   torch.cuda.empty_cache()

# %%
model = YOLO("yolov8s.pt")

model.train(
    data="C:/Users/sksaa/OneDrive/Desktop/smartVision AI/smartvision_dataset/detection/data.yaml",
    epochs=50,
    imgsz=512,
    batch=4,
    name="yolo_custom"
)
# Out:
# Ultralytics 8.4.41  Python-3.10.5 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
# ...

# %%
model.val()
# Out:
# Ultralytics 8.4.41  Python-3.10.5 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
# Model summary (fused): 73 layers, 11,135,646 parameters, 0 gradients, 28.5 GFLOPs
# val: Fast image access  (ping: 0.20.0 ms, read: 136.247.3 MB/s, size: 117.0 KB)
# val: Scanning C:\Users\sksaa\OneDrive\Desktop\smartVision AI\smartvision_dataset\detection\labels.cache... 11050 images, 0 backgrounds, 8467 corrupt: 100% ━━━━━━━━━━━━ 11050/11050  0.0s
# train: C:\Users\sksaa\OneDrive\Desktop\smartVision AI\smartvision_dataset\detection\images\image_000001.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0362      1.3258      1.1337      1.0276      1.0265      1.3846]
# train: C:\Users\sksaa\OneDrive\Desktop\smartVision AI\smartvision_dataset\detection\images\image_000002.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0362      1.3258      1.1337      1.0276      1.0265      1.3846]
# ...

# %%
model = YOLO(r"C:\Users\sksaa\OneDrive\Desktop\smartVision AI\notebook\runs\detect\yolo_custom-7\weights\best.pt")

results = model(r"C:\Users\sksaa\OneDrive\Desktop\smartVision AI\smartvision_dataset\detection\images\image_000010.jpg") #, save=True)
# Out:
# image 1/1 C:\Users\sksaa\OneDrive\Desktop\smartVision AI\smartvision_dataset\detection\images\image_000010.jpg: 352x512 1 person, 1 bicycle, 1 cat, 1 dog, 67.5ms
# Speed: 3.0ms preprocess, 67.5ms inference, 2.6ms postprocess per image at shape (1, 3, 352, 512)

# %%
from PIL import Image
Image.open("runs/detect/predict/test.jpg")
